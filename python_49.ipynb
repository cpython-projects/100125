# %%
absolute_path = "C:\\Users\\User\\Documents\\file.txt"
print(absolute_path)
# Out:
# C:\Users\User\Documents\file.txt

# %%
import os

# %%
os.getcwd()
# Out:
# 'D:\\ICH\\python_basic\\100125'

# %%
os.chdir('..')

# %%
os.getcwd()
# Out:
# 'D:\\ICH\\python_basic'

# %%
os.chdir('100125')

# %%
print(os.getcwd())
# Out:
# D:\ICH\python_basic\100125

# %%
help(os.getcwd)
# Out:
# Help on built-in function getcwd in module nt:
#
# getcwd()
#     Return a unicode string representing the current working directory.

# %%
file_path = "python_49.ipynb"
if os.path.exists(file_path):
    print(f"Файл '{file_path}' существует.")
else:
    print(f"Файл '{file_path}' не найден.")

directory_path = "example_folder"
if os.path.exists(directory_path):
    print(f"Директория '{directory_path}' существует.")
else:
    print(f"Директория '{directory_path}' не найдена.")
# Out:
# Файл 'python_49.ipynb' существует.
# Директория 'example_folder' не найдена.

# %%
os.listdir('.git')
# Out:
# ['COMMIT_EDITMSG',
#  'config',
#  'description',
#  'HEAD',
#  'hooks',
#  'index',
#  'info',
#  'logs',
#  'objects',
#  'refs']

# %%
os.listdir('.')
# Out:
# ['.git',
#  '.gitignore',
#  '.ipynb_checkpoints',
#  '.venv',
#  'collections_add.ipynb',
#  'dict_additional_part_1.ipynb',
#  'dict_additional_part_2.ipynb',
#  'lambda_add.ipynb',
#  'list_additional.ipynb',
#  'pythion_43.ipynb',
#  'python_04.ipynb',
#  'python_06.ipynb',
#  'python_07.ipynb',
#  'python_08.ipynb',
#  'python_10.ipynb',
#  'python_11.ipynb',
#  'python_12.ipynb',
#  'python_14.ipynb',
#  'python_15.ipynb',
#  'python_16.ipynb',
#  'python_18.ipynb',
#  'python_19.ipynb',
#  'python_20.ipynb',
#  'python_22.ipynb',
#  'python_23.ipynb',
#  'python_23_1.ipynb',
#  'python_24.ipynb',
#  'python_27.ipynb',
#  'python_28.ipynb',
#  'python_28_1.ipynb',
#  'python_28_2.ipynb',
#  'python_30.ipynb',
#  'python_31.ipynb',
#  'python_32.ipynb',
#  'python_34.ipynb',
#  'python_35_1.ipynb',
#  'python_36.ipynb',
#  'python_38.ipynb',
#  'python_39.ipynb',
#  'python_40.ipynb',
#  'python_42.ipynb',
#  'python_44.ipynb',
#  'python_45.ipynb',
#  'python_48.ipynb',
# ...

# %%
dir_path = "example_folder"
if not os.path.exists(dir_path):
    os.mkdir(dir_path)
    print(f"Директория '{dir_path}' создана.")
else:
    print(f"Директория '{dir_path}' существует.")
# Out:
# Директория 'example_folder' создана.

# %%
# Создание вложенных директорий
os.makedirs("parent_folder/child_folder", exist_ok=True)
print("Вложенные директории 'parent_folder/child_folder' созданы.")
# Out:
# Вложенные директории 'parent_folder/child_folder' созданы.

# %%
os.path.isfile('python_49.ipynb')
# Out:
# True

# %%
os.path.isdir('python_49.ipynb')
# Out:
# False

# %%
os.rename('python_48.ipynb', 'python_48_new.ipynb')

# %%
open('test.txt', 'w').close()

# %%
os.remove('test.txt')

# %%
os.rmdir('example_folder')

# %%
path = "/main/subdirectory/example.txt"

# %%
# Разделение пути на директорию и файл
directory, file = os.path.split(path)
print(directory)
print(file)
# Out:
# /main/subdirectory
# example.txt

# %%
print(f"Имя файла: {os.path.basename(path)}")
# Out:
# Имя файла: example.txt

# %%
print(f"Директория: {os.path.dirname(path)}")
# Out:
# Директория: /main/subdirectory

# %%
# Относительный путь
relative_path = "example.txt"
# Преобразование в абсолютный путь
absolute_path = os.path.abspath(relative_path)
print(f"Абсолютный путь: {absolute_path}")
# Out:
# Абсолютный путь: D:\ICH\python_basic\100125\example.txt

# %%
current_dir = os.getcwd()
sub_dir = "docs"
file_name = "data.txt"
full_path = os.path.join(current_dir, sub_dir, file_name)
print(f"Путь: {full_path}")
# Out:
# Путь: D:\ICH\python_basic\100125\docs\data.txt

# %%
# Рекурсивный обход директории
for root, dirs, files in os.walk("."):
    print(f"Текущая директория: {root}")
    print(f"Поддиректории: {dirs}")
    print(f"Файлы: {files}")
    print("-" * 50)
# Out:
# Текущая директория: .
# Поддиректории: ['.git', '.ipynb_checkpoints', '.venv', 'parent_folder']
# Файлы: ['.gitignore', 'collections_add.ipynb', 'dict_additional_part_1.ipynb', 'dict_additional_part_2.ipynb', 'lambda_add.ipynb', 'list_additional.ipynb', 'pythion_43.ipynb', 'python_04.ipynb', 'python_06.ipynb', 'python_07.ipynb', 'python_08.ipynb', 'python_10.ipynb', 'python_11.ipynb', 'python_12.ipynb', 'python_14.ipynb', 'python_15.ipynb', 'python_16.ipynb', 'python_18.ipynb', 'python_19.ipynb', 'python_20.ipynb', 'python_22.ipynb', 'python_23.ipynb', 'python_23_1.ipynb', 'python_24.ipynb', 'python_27.ipynb', 'python_28.ipynb', 'python_28_1.ipynb', 'python_28_2.ipynb', 'python_30.ipynb', 'python_31.ipynb', 'python_32.ipynb', 'python_34.ipynb', 'python_35_1.ipynb', 'python_36.ipynb', 'python_38.ipynb', 'python_39.ipynb', 'python_40.ipynb', 'python_42.ipynb', 'python_44.ipynb', 'python_45.ipynb', 'python_48_new.ipynb', 'python_49.ipynb', 'set_additional.ipynb']
# ...

# %%
# Поиск всех .txt файлов
for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".txt"):
            print(f"Найден файл: {os.path.join(root, file)}")
# Out:
# Найден файл: .\.venv\Lib\site-packages\pip\_vendor\vendor.txt
# Найден файл: .\.venv\Lib\site-packages\pip-24.0.dist-info\AUTHORS.txt
# Найден файл: .\.venv\Lib\site-packages\pip-24.0.dist-info\entry_points.txt
# Найден файл: .\.venv\Lib\site-packages\pip-24.0.dist-info\LICENSE.txt
# Найден файл: .\.venv\Lib\site-packages\pip-24.0.dist-info\top_level.txt
