# %% [markdown]
# Task 4
# Даны два списка: названия продуктов и их цены. Создайте словарь, где ключи — названия продуктов, а значения — их цены.
# ```python
# products = ["Яблоко", "Банан", "Груша"]
# prices = [100, 80, 120]
# ```

# %% [markdown]
# Дан список клиентов, каждый клиент представлен словарем с полями: "id", "имя", "возраст", "город".
# ```python
# [
#     {"id": 1, "имя": "Анна", "возраст": 25, "город": "Берлин"},
#     {"id": 2, "имя": "Иван", "возраст": 30, "город": "Берлин"},
#     {"id": 3, "имя": "Ольга", "возраст": 22, "город": "Вена"}
# ]
# ```
# Напишите функцию, которая принимает список клиентов и возвращает словарь, где ключи — города, а значения — списки клиентов из этих городов.

# %% [markdown]
# Task 2
# Дан список сотрудников, где каждый сотрудник представлен словарем с полями "имя", "отдел".
# ```python
# [
#     {"имя": "Анна", "отдел": "Маркетинг"},
#     {"имя": "Иван", "отдел": "Продажи"},
#     {"имя": "Ольга", "отдел": "Маркетинг"}
# ]
# ```
# Создайте функцию, которая группирует сотрудников по отделам.

# %% [markdown]
# Task 3
# Напишите программу, которая создает словарь студентов, где ключи — номера студенческих билетов, а значения — информация о каждом студенте (имя, возраст, факультет).
# ```python
# {
#     "1001": {"имя": "Анна", "возраст": 20, "факультет": "Экономика"},
#     "1002": {"имя": "Иван", "возраст": 21, "факультет": "Математика"}
# }
# ```

# %% [markdown]
# Task 5
# Дан словарь, где ключи — товары, а значения — их цены. Отсортируйте товары по убыванию цен и верните отсортированный словарь.
# ```python
# {
#     "Яблоко": 100,
#     "Банан": 80,
#     "Груша": 120
# }
# ```

# %% [markdown]
# **Task 6**
# Дан словарь, где ключи — месяцы, а значения — продажи. Напишите функцию, которая возвращает словарь с процентными изменениями продаж по месяцам.
# ```python
# {
#     "Январь": 1200,
#     "Февраль": 1100,
#     "Март": 1300
# }
# ```

# %% [markdown]
# **Task 7**
# Даны два словаря: "ученики" (с ключами — имена и значениями — количество посещений) и "возраст" (ключи — имена, значения — возраст). Найдите средний возраст учеников с посещениями более 10.
# ```python
# attendens = {"Анна": 12, "Иван": 8, "Ольга": 15}
# ages = {"Анна": 25, "Иван": 30, "Ольга": 22}
# ```

# %% [markdown]
# **Task 8**
# Дан словарь с данными по продажам, где ключи — дни месяца, а значения — сумма продаж. Найдите дни с самыми высокими отклонениями от среднего значения.
# ```python
# {
#     1: 500, 2: 700, 3: 300, 4: 800, 5: 200
# }
# ```

# %% [markdown]
# **Task 9**
# Дан список заказов, каждый из которых представлен словарем (товар, цена, количество). Верните словарь с товарами и их общими количествами.
# ```python
# [
#     {"товар": "Яблоко", "цена": 100, "количество": 2},
#     {"товар": "Банан", "цена": 80, "количество": 3},
#     {"товар": "Яблоко", "цена": 100, "количество": 1}
# ]
# ```python

# %% [markdown]
# **Task 10**
# Дан словарь, где ключи — имена сотрудников, а значения — отделы. Напишите функцию, которая возвращает словарь, где ключи — отделы, а значения — списки сотрудников.
# ```python
# {
#     "Анна": "Маркетинг",
#     "Иван": "Продажи",
#     "Ольга": "Маркетинг"
# }
# ```
